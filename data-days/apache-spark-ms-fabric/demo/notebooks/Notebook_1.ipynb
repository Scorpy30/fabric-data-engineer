# %%
# Welcome to your new notebook
# Type here in the cell editor to add code!

# %%
# %%configure
# {
#    "conf": {
#        "spark.native.enabled": "true",
#        "spark.shuffle.manager": "org.apache.spark.shuffle.sort.ColumnarShuffleManager"
#    }
# }
# Out:
# StatementMeta(, 9645bef4-99ec-4b17-90ce-da767620379f, -1, Finished, Available, Finished, True)

# %%
spark.conf.get("spark.native.enabled")
# Out:
# StatementMeta(, 9645bef4-99ec-4b17-90ce-da767620379f, 3, Finished, Available, Finished, False)
# 'true'

# %%
spark.conf.get("spark.shuffle.manager")
# Out:
# StatementMeta(, 9645bef4-99ec-4b17-90ce-da767620379f, 4, Finished, Available, Finished, False)
# 'org.apache.spark.shuffle.sort.ColumnarShuffleManager'

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.getOrCreate()
data = [("Tarush", 1), ("Copilot", 2)]
df = spark.createDataFrame(data, ["Name", "Value"])
df.show()
# Out:
# StatementMeta(, 92f2a0c2-1d9d-467c-b36a-d3cd9d0e2d3b, 3, Finished, Available, Finished, False)
# +-------+-----+
# |   Name|Value|
# +-------+-----+
# | Tarush|    1|
# |Copilot|    2|
# +-------+-----+
